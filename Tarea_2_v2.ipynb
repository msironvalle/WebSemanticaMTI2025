# %% [markdown]
# <a href="https://colab.research.google.com/github/msironvalle/WebSemanticaMTI2025/blob/main/Tarea_2_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primer Set de datos

# %%
# !pip install rdflib
# !pip install sparqlwrapper
# Out:
# Collecting rdflib
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib) (3.2.1)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 12.9 MB/s eta 0:00:00
# Installing collected packages: rdflib
# Successfully installed rdflib-7.1.3
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.11/dist-packages (from sparqlwrapper) (7.1.3)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (3.2.1)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: sparqlwrapper
# Successfully installed sparqlwrapper-2.0.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import rdflib
from rdflib import Graph

# %%
# =====================================
# 4) Definición de la ruta a tu archivo RDF en Drive
# =====================================
rdf_file_path = "/content/drive/My Drive/output_PasosFronterizos_7.rdf"

# %%
g = Graph()

# Si tu archivo está en formato Turtle (extensión .ttl o con prefijos en Turtle)
# especifica format="turtle". Si fuera RDF/XML, usar format="xml".
g.parse(rdf_file_path, format="turtle")

# =====================================
# 6) Ejemplo de consultas SPARQL
# =====================================
# 6.1) Consulta para obtener el paso fronterizo con la mayor altura
query_mayor_altura = """
PREFIX ex: <http://example.org/pasos_fronterizos#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?paso ?nombre ?altura
WHERE {
  # ?paso a ex:PasoFronterizo ;
        ex:nombre ?nombre ;
        ex:altura ?altura .
}
ORDER BY DESC(?altura)
LIMIT 1
"""

# 6.2) Consulta para obtener el paso fronterizo más al sur (lat más pequeña)
query_mas_al_sur = """
PREFIX ex: <http://example.org/pasos_fronterizos#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?paso ?nombre ?lat
WHERE {
  # ?paso a ex:PasoFronterizo ;
        ex:nombre ?nombre ;
        geo:lat ?lat .
}
ORDER BY ASC(?lat)
LIMIT 1
"""

# =====================================
# 7) Ejecutar consultas y mostrar resultados
# =====================================
# Consulta 1: Paso fronterizo de mayor altura
print("==== Paso fronterizo de mayor altura ====")
for row in g.query(query_mayor_altura):
    print(f"URI: {row.paso}, Nombre: {row.nombre}, Altura: {row.altura}")

print()

# Consulta 2: Paso fronterizo más al sur
print("==== Paso fronterizo más al sur ====")
for row in g.query(query_mas_al_sur):
    print(f"URI: {row.paso}, Nombre: {row.nombre}, Latitud: {row.lat}")
# Out:
# ==== Paso fronterizo de mayor altura ====
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_15, Nombre: Coyhaique, Altura: 795
#
# ==== Paso fronterizo más al sur ====
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_31, Nombre: Bellavista, Latitud: -54

# %% [markdown]
# ## Consulta Federada

# %%
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON

# ==============================================
# 3. Cargar el RDF local en un grafo
#    Ajusta la ruta si fuera distinto el archivo
# ==============================================
local_rdf_path = "/content/drive/My Drive/output_PasosFronterizos_7.rdf"

g_local = Graph()
# Tu RDF está en Turtle, así que usamos 'turtle'
g_local.parse(local_rdf_path, format="turtle")

# ==============================================
# 4. Consulta local para obtener datos de "pasos fronterizos"
# ==============================================
query_local = """
PREFIX ex: <http://example.org/pasos_fronterizos#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>

SELECT ?paso ?nombre ?altura ?region ?unidad ?lat ?long
WHERE {
  # ?paso a ex:PasoFronterizo ;
        ex:nombre ?nombre ;
        ex:altura ?altura ;
        ex:region ?region ;
        ex:unidad ?unidad ;
        geo:lat ?lat ;
        geo:long ?long .
}
"""

results_local = g_local.query(query_local)

print("=== PASOS FRONTERIZOS EN RDF LOCAL ===\n")
nombres_locales = []
for row in results_local:
    paso_uri = str(row.paso)
    nombre = str(row.nombre)
    altura = str(row.altura)
    region = str(row.region)
    unidad = str(row.unidad)
    lat = str(row.lat)
    long_ = str(row.long)

    print(f"URI: {paso_uri}")
    print(f"  Nombre: {nombre}")
    print(f"  Altura: {altura} {unidad}")
    print(f"  Región: {region}")
    print(f"  Coordenadas: ({lat}, {long_})")
    print("-"*50)

    nombres_locales.append(nombre)

# ==============================================
# 5. Consulta a Wikidata: todos los "border crossings" en Chile
#    (esto es una segunda fuente de datos)
# ==============================================
# wdt:P31/wdt:P279* wd:Q28769114 => instancia o subclase de "border crossing"
# wdt:P17 wd:Q298               => el país es Chile
# El SERVICE wikibase:label permite traer etiquetas en español.
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

query_wikidata = """
SELECT ?paso ?pasoLabel
WHERE {
  # ?paso wdt:P31/wdt:P279* wd:Q28769114 ;
        wdt:P17 wd:Q298 .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "es,en". }
}
ORDER BY ?pasoLabel
"""

sparql.setQuery(query_wikidata)
res_wikidata = sparql.query().convert()

# Transformamos resultados en una lista
pasos_wikidata = []
for b in res_wikidata["results"]["bindings"]:
    qitem = b["paso"]["value"]
    label = b.get("pasoLabel", {}).get("value", "")
    pasos_wikidata.append((qitem, label))

print("\n=== PASOS INTERNACIONALES DE CHILE SEGÚN WIKIDATA ===\n")
for q, lbl in pasos_wikidata:
    print(f"- {lbl} -> {q}")

# ==============================================
# 6. (Opcional) Ver coincidencias de nombres
#    entre el RDF local y Wikidata
# ==============================================
print("\n=== COINCIDENCIAS DE NOMBRES (Local vs Wikidata) ===\n")

set_local = set(nombres_locales)
for q, lbl in pasos_wikidata:
    # Chequeamos si el label WD coincide con un nombre local exacto
    if lbl in set_local:
        print(f"Coincide: {lbl}  (Q-item: {q})")
# Out:
# === PASOS FRONTERIZOS EN RDF LOCAL ===
#
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_1
#   Nombre: Salar de Ollague
#   Altura: 4 Metros
#   Región: Antofagasta
#   Coordenadas: (-21.2230556, -68.24944444)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_2
#   Nombre: Portezuelo de Cajón
#   Altura: 4 Metros
#   Región: Antofagasta
#   Coordenadas: (-22.9161111, -67.79944444)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_3
#   Nombre: San Pedro de Atacama
#   Altura: 3 Metros
#   Región: Antofagasta
#   Coordenadas: (-22.9105556, -68.19361111)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_4
#   Nombre: Jama
#   Altura: 4 Metros
#   Región: Antofagasta
#   Coordenadas: (-23.2369444, -67.02277778)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_5
#   Nombre: Sico
#   Altura: 4 Metros
#   Región: Antofagasta
#   Coordenadas: (-23.8736111, -67.15694444)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_6
#   Nombre: Socompa
#   Altura: 4 Metros
#   Región: Antofagasta
#   Coordenadas: (-24.4505556, -68.29027778)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_7
#   Nombre: Pino Hachado
#   Altura: 2 Metros
#   Región: La Araucanía
#   Coordenadas: (-38.6666667, -70.9)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_8
#   Nombre: Icalma
#   Altura: 1 Metros
#   Región: La Araucanía
#   Coordenadas: (-38.8425, -71.28722222)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_9
#   Nombre: Mamuil Malal
#   Altura: 1 Metros
#   Región: La Araucanía
#   Coordenadas: (-39.5833333, -71.46666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_10
#   Nombre: Concordia
#   Altura: 74 Metros
#   Región: Arica y Parinacota
#   Coordenadas: (-18.3, -70.31666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_11
#   Nombre: Chungará-Tambi Quemado
#   Altura: 5 Metros
#   Región: Arica y Parinacota
#   Coordenadas: (-18.2833333, -69.06666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_12
#   Nombre: Visviri
#   Altura: 4 Metros
#   Región: Arica y Parinacota
#   Coordenadas: (-17.5833333, -69.46666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_13
#   Nombre: San Francisco
#   Altura: 5 Metros
#   Región: Atacama
#   Coordenadas: (-26.8666667, -68.3)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_14
#   Nombre: Pircas Negras
#   Altura: 4 Metros
#   Región: Atacama
#   Coordenadas: (-28.0666667, -69.3)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_15
#   Nombre: Coyhaique
#   Altura: 795 Metros
#   Región: Aisén del General Carlos Ibáñez del Campo
#   Coordenadas: (-45.5166667, -71.55)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_16
#   Nombre: Huemules
#   Altura: 500 Metros
#   Región: Aisén del General Carlos Ibáñez del Campo
#   Coordenadas: (-45.9166667, -71.73333333)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_17
#   Nombre: Río Jeinimeni
#   Altura: 255 Metros
#   Región: Aisén del General Carlos Ibáñez del Campo
#   Coordenadas: (-45.5666667, -71.66666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_18
#   Nombre: Pichachen
#   Altura: 2 Metros
#   Región: BioBío
#   Coordenadas: (-37.45, -71.13333333)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_19
#   Nombre: Agua Negra
#   Altura: 5 Metros
#   Región: Coquimbo
#   Coordenadas: (-30.1833333, -69.81666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_20
#   Nombre: Futaleufu
#   Altura: 365 Metros
#   Región: Los Lagos
#   Coordenadas: (-43.1763889, -71.7575)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_21
#   Nombre: Río Encuentro
#   Altura: 353 Metros
#   Región: Los Lagos
#   Coordenadas: (-43.5877778, -71.70694444)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_22
#   Nombre: Vicente Perez Rosales
#   Altura: 200 Metros
#   Región: Los Lagos
#   Coordenadas: (-41.0588889, -72.02472222)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_23
#   Nombre: Paso Cardenal Samoré
#   Altura: 1 Metros
#   Región: Los Lagos
#   Coordenadas: (-41.7166667, -71.95)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_24
#   Nombre: Paso Carirriñe
#   Altura: 1 Metros
#   Región: Los Ríos
#   Coordenadas: (-39.7833333, -71.68333333)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_25
#   Nombre: Paso Huahum
#   Altura: 625 Metros
#   Región: Los Ríos
#   Coordenadas: (-40.1, -71.66666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_26
#   Nombre: Río Don Guillermo
#   Altura: 260 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-51.25, -72.25)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_27
#   Nombre: Dorotea
#   Altura: 605 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-51.5833333, -72.33333333)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_28
#   Nombre: Laurita Casa Viejas
#   Altura: 240 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-51.6833333, -72.3)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_29
#   Nombre: Integración Austral
#   Altura: 165 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-52.1333333, -69.51666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_30
#   Nombre: San Sebastián
#   Altura: 10 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-53.3166667, -68.6)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_31
#   Nombre: Bellavista
#   Altura: 0 Metros
#   Región: Magallanes y de la Antártica Chilena
#   Coordenadas: (-54, -68.68333333)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_32
#   Nombre: Pehuenche
#   Altura: 3 Metros
#   Región: Maule
#   Coordenadas: (-35.9833333, -70.4)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_33
#   Nombre: Vergara
#   Altura: 3 Metros
#   Región: Maule
#   Coordenadas: (-35.1333333, -70.46666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_34
#   Nombre: Colchane Pisiga
#   Altura: 4 Metros
#   Región: Tarapacá
#   Coordenadas: (-19.2666667, -68.61666667)
# --------------------------------------------------
# URI: http://example.org/pasos_fronterizos#PasoFronterizo_35
#   Nombre: Sistema Cristo Redentor
#   Altura: 3 Metros
#   Región: Valparaíso
#   Coordenadas: (-32.8166667, -70.06666667)
# --------------------------------------------------
#
# === PASOS INTERNACIONALES DE CHILE SEGÚN WIKIDATA ===
#
#
# === COINCIDENCIAS DE NOMBRES (Local vs Wikidata) ===

# %% [markdown]
# # Segundo Set de Datos

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL para obtener los códigos postales...")

# Ejecutar la consulta
results = g.query(sparql_query)

# Contar colegios por área postal (2 primeras letras del código postal)
area_counts = collections.Counter()

for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer las primeras 2 letras
    area_counts[area_code] += 1

# Mostrar resultados
print("\n📌 Cantidad de colegios por área postal:")
for area, count in sorted(area_counts.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL para obtener los códigos postales...
#
# 📌 Cantidad de colegios por área postal:
# Área Postal: DH, Cantidad de Escuelas: 116
# Área Postal: DL, Cantidad de Escuelas: 104
# Área Postal: SR, Cantidad de Escuelas: 30
# Área Postal: TS, Cantidad de Escuelas: 16
# Área Postal: NE, Cantidad de Escuelas: 1

# %% [markdown]
# Federada

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections
from SPARQLWrapper import SPARQLWrapper, JSON

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL para obtener los códigos postales...")

# Ejecutar la consulta
results = g.query(sparql_query)

# Extraer las primeras 2 letras de cada código postal (área postal)
area_codes = set()
for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer las primeras 2 letras
    area_codes.add(area_code)

print(f"\n📌 Áreas postales detectadas en los datos locales: {', '.join(area_codes)}")

# --- CONSULTA FEDERADA A WIKIDATA ---
print("\n🔹 Consultando colegios públicos en Wikidata según área postal...")

# Configurar la consulta SPARQL en Wikidata
wikidata_sparql = """
SELECT ?school ?schoolLabel ?postcode WHERE {
  # ?school wdt:P31 wd:Q3914;  # Instancia de "escuela"
          wdt:P17 wd:Q145;   # Ubicada en Reino Unido
          wdt:P281 ?postcode. # Código postal

  # Filtrar por las áreas postales detectadas en el RDF local
  FILTER (""" + " || ".join([f"STRSTARTS(?postcode, \"{code}\")" for code in area_codes]) + """ )

  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
"""

# Conectar con Wikidata y ejecutar la consulta
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(wikidata_sparql)
sparql.setReturnFormat(JSON)
results_wikidata = sparql.query().convert()

# Mostrar resultados obtenidos de Wikidata
print("\n📌 Colegios públicos en Reino Unido según área postal (desde Wikidata):")
for result in results_wikidata["results"]["bindings"]:
    school_name = result["schoolLabel"]["value"]
    school_postcode = result["postcode"]["value"]
    print(f"🏫 {school_name} - Código Postal: {school_postcode}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL para obtener los códigos postales...
#
# 📌 Áreas postales detectadas en los datos locales: NE, DH, SR, TS, DL
#
# 🔹 Consultando colegios públicos en Wikidata según área postal...
#
# 📌 Colegios públicos en Reino Unido según área postal (desde Wikidata):
# 🏫 Argyle House School - Código Postal: SR2 7LA
# 🏫 Barnard Castle School - Código Postal: DL12 8UN
# 🏫 Chorister School - Código Postal: DH1 3EL
# 🏫 Eastbourne Church of England Academy - Código Postal: DL1 1LL
# 🏫 The Grangefield Academy - Código Postal: TS18 4LE
# 🏫 Grindon Hall Christian School - Código Postal: SR4 8PG
# 🏫 St John's School & Sixth Form College - A Catholic Academy - Código Postal: DL14 6JT
# 🏫 St Joseph's R.C. Middle School - Código Postal: NE46 2DD
# 🏫 St Leonard's Catholic School, Durham - Código Postal: DH1 4NG
# 🏫 St Wilfrid's RC College - Código Postal: NE34 0QA
# 🏫 St Joseph's Catholic Academy - Código Postal: NE31 2ET
# 🏫 The Academy at Shotton Hall - Código Postal: SR8 1AU
# 🏫 Newcastle School for Boys - Código Postal: NE3 4ES
# 🏫 Royal Grammar School - Código Postal: NE2 4DX
# 🏫 The Wensleydale School - Código Postal: DL8 5HX
# 🏫 The Wensleydale School - Código Postal: DL8 5HY
# 🏫 Thomas Hepburn Community Academy - Código Postal: NE10 9UZ
# 🏫 Trinity Catholic College - Código Postal: TS4 3JW
# 🏫 Valley Gardens Middle School - Código Postal: NE25 9AQ
# 🏫 Wellfield Middle School - Código Postal: NE25 9QW
# 🏫 Red House School - Código Postal: TS20 1DX
# 🏫 Whickham School - Código Postal: NE16 5AR
# 🏫 Woodham Academy - Código Postal: DL5 4AX
# 🏫 Yarm School - Código Postal: TS15 9EJ
# 🏫 The King Edward VI Academy - Código Postal: NE61 1DN
# 🏫 Churchill Community College - Código Postal: NE28 7TN
# 🏫 Hetton School - Código Postal: DH5 9JZ
# 🏫 St Robert of Newminster Catholic School - Código Postal: NE38 8AF
# 🏫 North Gosforth Academy - Código Postal: NE13 6EJ
# 🏫 Walker Riverside Academy - Código Postal: NE6 4AW
# 🏫 Haughton Academy - Código Postal: DL1 2AN
# 🏫 Longfield Academy, Darlington - Código Postal: DL3 0HT
# 🏫 St Hild's Church of England Voluntary Aided School - Código Postal: TS24 9PB
# 🏫 The Hermitage Academy - Código Postal: DH2 3AD

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo RDF cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios desde RDF
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...")

# Ejecutar la consulta en el RDF local
results = g.query(sparql_query)

# Contar colegios por área postal (primeras 2 letras del código postal)
area_counts_local = collections.Counter()

for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer primeras 2 letras
    area_counts_local[area_code] += 1

print("\n📌 Cantidad de escuelas por área postal en RDF local:")
for area, count in sorted(area_counts_local.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- CONSULTA FEDERADA A WIKIDATA ---
print("\n🔹 Consultando cantidad de escuelas en Wikidata por área postal...")

# Definir la consulta SPARQL en Wikidata
wikidata_sparql = """
SELECT ?postcode (COUNT(?school) AS ?count) WHERE {
  # ?school wdt:P31 wd:Q3914;  # Instancia de "escuela"
          wdt:P17 wd:Q145;   # Ubicada en Reino Unido
          wdt:P281 ?postcode. # Código postal
}
GROUP BY ?postcode
"""

# Conectar con Wikidata y ejecutar la consulta
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(wikidata_sparql)
sparql.setReturnFormat(JSON)
results_wikidata = sparql.query().convert()

# Contar colegios por área postal en Wikidata
area_counts_wikidata = collections.Counter()

for result in results_wikidata["results"]["bindings"]:
    postcode = result["postcode"]["value"]  # Obtener código postal
    area_code = postcode[:2]  # Extraer primeras 2 letras
    count = int(result["count"]["value"])  # Convertir a entero
    area_counts_wikidata[area_code] += count  # Contar colegios por área

print("\n📌 Cantidad de escuelas por área postal en Wikidata:")
for area, count in sorted(area_counts_wikidata.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- COMPARAR DATOS ENTRE RDF LOCAL Y WIKIDATA ---
print("\n🔹 Comparando datos entre RDF local y Wikidata...")

# Crear un DataFrame para visualizar la comparación
data = []
for area in set(area_counts_local.keys()).union(area_counts_wikidata.keys()):
    local_count = area_counts_local.get(area, 0)
    wikidata_count = area_counts_wikidata.get(area, 0)
    data.append([area, local_count, wikidata_count])

# Convertir a DataFrame
df_comparison = pd.DataFrame(data, columns=["Área Postal", "Escuelas en RDF Local", "Escuelas en Wikidata"])
df_comparison = df_comparison.sort_values(by="Escuelas en Wikidata", ascending=False)

# Mostrar la tabla
import ace_tools as tools
tools.display_dataframe_to_user(name="Comparación de Escuelas por Área Postal", dataframe=df_comparison)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo RDF cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...
#
# 📌 Cantidad de escuelas por área postal en RDF local:
# Área Postal: DH, Cantidad de Escuelas: 116
# Área Postal: DL, Cantidad de Escuelas: 104
# Área Postal: SR, Cantidad de Escuelas: 30
# Área Postal: TS, Cantidad de Escuelas: 16
# Área Postal: NE, Cantidad de Escuelas: 1
#
# 🔹 Consultando cantidad de escuelas en Wikidata por área postal...
#
# 📌 Cantidad de escuelas por área postal en Wikidata:
# Área Postal: RG, Cantidad de Escuelas: 28
# Área Postal: GU, Cantidad de Escuelas: 27
# Área Postal: RH, Cantidad de Escuelas: 23
# Área Postal: OX, Cantidad de Escuelas: 20
# Área Postal: SW, Cantidad de Escuelas: 18
# Área Postal: KT, Cantidad de Escuelas: 18
# Área Postal: TN, Cantidad de Escuelas: 17
# Área Postal: SE, Cantidad de Escuelas: 16
# Área Postal: SL, Cantidad de Escuelas: 16
# Área Postal: BS, Cantidad de Escuelas: 16
# Área Postal: PO, Cantidad de Escuelas: 15
# Área Postal: SY, Cantidad de Escuelas: 14
# Área Postal: WS, Cantidad de Escuelas: 14
# Área Postal: NE, Cantidad de Escuelas: 14
# Área Postal: SP, Cantidad de Escuelas: 13
# Área Postal: DE, Cantidad de Escuelas: 12
# Área Postal: CV, Cantidad de Escuelas: 12
# Área Postal: DN, Cantidad de Escuelas: 12
# Área Postal: LL, Cantidad de Escuelas: 12
# Área Postal: IP, Cantidad de Escuelas: 11
# Área Postal: BN, Cantidad de Escuelas: 11
# Área Postal: SO, Cantidad de Escuelas: 11
# Área Postal: BA, Cantidad de Escuelas: 11
# Área Postal: WR, Cantidad de Escuelas: 10
# Área Postal: MK, Cantidad de Escuelas: 10
# Área Postal: ST, Cantidad de Escuelas: 10
# Área Postal: BH, Cantidad de Escuelas: 10
# Área Postal: TW, Cantidad de Escuelas: 10
# Área Postal: SN, Cantidad de Escuelas: 10
# Área Postal: LE, Cantidad de Escuelas: 9
# Área Postal: NW, Cantidad de Escuelas: 9
# Área Postal: SK, Cantidad de Escuelas: 9
# Área Postal: HP, Cantidad de Escuelas: 9
# Área Postal: NN, Cantidad de Escuelas: 9
# Área Postal: WV, Cantidad de Escuelas: 8
# Área Postal: DL, Cantidad de Escuelas: 8
# Área Postal: EX, Cantidad de Escuelas: 8
# Área Postal: SA, Cantidad de Escuelas: 8
# Área Postal: PE, Cantidad de Escuelas: 8
# Área Postal: NR, Cantidad de Escuelas: 8
# Área Postal: B2, Cantidad de Escuelas: 8
# Área Postal: PL, Cantidad de Escuelas: 8
# Área Postal: N1, Cantidad de Escuelas: 8
# Área Postal: WA, Cantidad de Escuelas: 8
# Área Postal: B1, Cantidad de Escuelas: 7
# Área Postal: NG, Cantidad de Escuelas: 7
# Área Postal: CR, Cantidad de Escuelas: 7
# Área Postal: B7, Cantidad de Escuelas: 7
# Área Postal: S6, Cantidad de Escuelas: 7
# Área Postal: YO, Cantidad de Escuelas: 6
# Área Postal: GL, Cantidad de Escuelas: 6
# Área Postal: E1, Cantidad de Escuelas: 6
# Área Postal: B3, Cantidad de Escuelas: 6
# Área Postal: DT, Cantidad de Escuelas: 6
# Área Postal: DY, Cantidad de Escuelas: 6
# Área Postal: ME, Cantidad de Escuelas: 6
# Área Postal: LN, Cantidad de Escuelas: 6
# Área Postal: B9, Cantidad de Escuelas: 6
# Área Postal: S4, Cantidad de Escuelas: 5
# Área Postal: W1, Cantidad de Escuelas: 5
# Área Postal: N2, Cantidad de Escuelas: 5
# Área Postal: TS, Cantidad de Escuelas: 5
# Área Postal: CW, Cantidad de Escuelas: 5
# Área Postal: NP, Cantidad de Escuelas: 5
# Área Postal: TA, Cantidad de Escuelas: 5
# Área Postal: PR, Cantidad de Escuelas: 5
# Área Postal: UB, Cantidad de Escuelas: 5
# Área Postal: CT, Cantidad de Escuelas: 5
# Área Postal: CF, Cantidad de Escuelas: 5
# Área Postal: SG, Cantidad de Escuelas: 4
# Área Postal: CB, Cantidad de Escuelas: 4
# Área Postal: DH, Cantidad de Escuelas: 4
# Área Postal: HU, Cantidad de Escuelas: 4
# Área Postal: CH, Cantidad de Escuelas: 4
# Área Postal: E3, Cantidad de Escuelas: 4
# Área Postal: CO, Cantidad de Escuelas: 4
# Área Postal: EN, Cantidad de Escuelas: 4
# Área Postal: TQ, Cantidad de Escuelas: 4
# Área Postal: BB, Cantidad de Escuelas: 4
# Área Postal: DA, Cantidad de Escuelas: 4
# Área Postal: HA, Cantidad de Escuelas: 3
# Área Postal: SR, Cantidad de Escuelas: 3
# Área Postal: IG, Cantidad de Escuelas: 3
# Área Postal: RM, Cantidad de Escuelas: 3
# Área Postal: EC, Cantidad de Escuelas: 3
# Área Postal: SM, Cantidad de Escuelas: 3
# Área Postal: LU, Cantidad de Escuelas: 3
# Área Postal: TD, Cantidad de Escuelas: 3
# Área Postal: L1, Cantidad de Escuelas: 3
# Área Postal: TF, Cantidad de Escuelas: 3
# Área Postal: M2, Cantidad de Escuelas: 2
# Área Postal: HR, Cantidad de Escuelas: 2
# Área Postal: M6, Cantidad de Escuelas: 2
# Área Postal: E7, Cantidad de Escuelas: 2
# Área Postal: S1, Cantidad de Escuelas: 2
# Área Postal: B4, Cantidad de Escuelas: 2
# Área Postal: W3, Cantidad de Escuelas: 2
# Área Postal: L2, Cantidad de Escuelas: 2
# Área Postal: M1, Cantidad de Escuelas: 2
# Área Postal: WD, Cantidad de Escuelas: 2
# Área Postal: WN, Cantidad de Escuelas: 2
# Área Postal: S3, Cantidad de Escuelas: 2
# Área Postal: TR, Cantidad de Escuelas: 2
# Área Postal: HG, Cantidad de Escuelas: 2
# Área Postal: S8, Cantidad de Escuelas: 2
# Área Postal: B6, Cantidad de Escuelas: 1
# Área Postal: B5, Cantidad de Escuelas: 1
# Área Postal: KA, Cantidad de Escuelas: 1
# Área Postal: CM, Cantidad de Escuelas: 1
# Área Postal: LS, Cantidad de Escuelas: 1
# Área Postal: HX, Cantidad de Escuelas: 1
# Área Postal: L3, Cantidad de Escuelas: 1
# Área Postal: W5, Cantidad de Escuelas: 1
# Área Postal: PH, Cantidad de Escuelas: 1
# Área Postal: E4, Cantidad de Escuelas: 1
# Área Postal: AL, Cantidad de Escuelas: 1
# Área Postal: PG, Cantidad de Escuelas: 1
# Área Postal: OL, Cantidad de Escuelas: 1
# Área Postal: L7, Cantidad de Escuelas: 1
# Área Postal: S7, Cantidad de Escuelas: 1
# Área Postal: S9, Cantidad de Escuelas: 1
# Área Postal: BT, Cantidad de Escuelas: 1
# Área Postal: E9, Cantidad de Escuelas: 1
# Área Postal: BR, Cantidad de Escuelas: 1
# Área Postal: BD, Cantidad de Escuelas: 1
# Área Postal: W2, Cantidad de Escuelas: 1
# Área Postal: FY, Cantidad de Escuelas: 1
#
# 🔹 Comparando datos entre RDF local y Wikidata...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-75-98d8bbbf7a5c> in <cell line: 0>()
#      94
#      95 # Mostrar la tabla
# ---> 96 import ace_tools as tools
#      97 tools.display_dataframe_to_user(name="Comparación de Escuelas por Área Postal", dataframe=df_comparison)
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from IPython.display import display  # <- 🔹 Corregido: Para mostrar la tabla en Google Colab

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo RDF cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios desde RDF
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...")

# Ejecutar la consulta en el RDF local
results = g.query(sparql_query)

# Contar colegios por área postal (primeras 2 letras del código postal)
area_counts_local = collections.Counter()

for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer primeras 2 letras
    area_counts_local[area_code] += 1

print("\n📌 Cantidad de escuelas por área postal en RDF local:")
for area, count in sorted(area_counts_local.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- CONSULTA FEDERADA A WIKIDATA ---
print("\n🔹 Consultando cantidad de escuelas en Wikidata por área postal...")

# Definir la consulta SPARQL en Wikidata
wikidata_sparql = """
SELECT ?postcode (COUNT(?school) AS ?count) WHERE {
  # ?school wdt:P31 wd:Q3914;  # Instancia de "escuela"
          wdt:P17 wd:Q145;   # Ubicada en Reino Unido
          wdt:P281 ?postcode. # Código postal
}
GROUP BY ?postcode
"""

# Conectar con Wikidata y ejecutar la consulta
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(wikidata_sparql)
sparql.setReturnFormat(JSON)
results_wikidata = sparql.query().convert()

# Contar colegios por área postal en Wikidata
area_counts_wikidata = collections.Counter()

for result in results_wikidata["results"]["bindings"]:
    postcode = result["postcode"]["value"]  # Obtener código postal
    area_code = postcode[:2]  # Extraer primeras 2 letras
    count = int(result["count"]["value"])  # Convertir a entero
    area_counts_wikidata[area_code] += count  # Contar colegios por área

print("\n📌 Cantidad de escuelas por área postal en Wikidata:")
for area, count in sorted(area_counts_wikidata.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- COMPARAR DATOS ENTRE RDF LOCAL Y WIKIDATA ---
print("\n🔹 Comparando datos entre RDF local y Wikidata...")

# Crear un DataFrame para visualizar la comparación
data = []
for area in set(area_counts_local.keys()).union(area_counts_wikidata.keys()):
    local_count = area_counts_local.get(area, 0)
    wikidata_count = area_counts_wikidata.get(area, 0)
    data.append([area, local_count, wikidata_count])

# Convertir a DataFrame
df_comparison = pd.DataFrame(data, columns=["Área Postal", "Escuelas en RDF Local", "Escuelas en Wikidata"])
df_comparison = df_comparison.sort_values(by="Escuelas en Wikidata", ascending=False)

# 🔹 Mostrar la tabla con Pandas en Google Colab
print("\n📌 Comparación de Escuelas por Área Postal:")
display(df_comparison)  # <- 🔹 CORREGIDO: Mostrar la tabla en Google Colab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo RDF cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...
#
# 📌 Cantidad de escuelas por área postal en RDF local:
# Área Postal: DH, Cantidad de Escuelas: 116
# Área Postal: DL, Cantidad de Escuelas: 104
# Área Postal: SR, Cantidad de Escuelas: 30
# Área Postal: TS, Cantidad de Escuelas: 16
# Área Postal: NE, Cantidad de Escuelas: 1
#
# 🔹 Consultando cantidad de escuelas en Wikidata por área postal...
#
# 📌 Cantidad de escuelas por área postal en Wikidata:
# Área Postal: RG, Cantidad de Escuelas: 28
# Área Postal: GU, Cantidad de Escuelas: 27
# Área Postal: RH, Cantidad de Escuelas: 23
# Área Postal: OX, Cantidad de Escuelas: 20
# Área Postal: SW, Cantidad de Escuelas: 18
# Área Postal: KT, Cantidad de Escuelas: 18
# Área Postal: TN, Cantidad de Escuelas: 17
# Área Postal: SE, Cantidad de Escuelas: 16
# Área Postal: SL, Cantidad de Escuelas: 16
# Área Postal: BS, Cantidad de Escuelas: 16
# Área Postal: PO, Cantidad de Escuelas: 15
# Área Postal: SY, Cantidad de Escuelas: 14
# Área Postal: WS, Cantidad de Escuelas: 14
# Área Postal: NE, Cantidad de Escuelas: 14
# Área Postal: SP, Cantidad de Escuelas: 13
# Área Postal: DE, Cantidad de Escuelas: 12
# Área Postal: CV, Cantidad de Escuelas: 12
# Área Postal: DN, Cantidad de Escuelas: 12
# Área Postal: LL, Cantidad de Escuelas: 12
# Área Postal: IP, Cantidad de Escuelas: 11
# Área Postal: BN, Cantidad de Escuelas: 11
# Área Postal: SO, Cantidad de Escuelas: 11
# Área Postal: BA, Cantidad de Escuelas: 11
# Área Postal: WR, Cantidad de Escuelas: 10
# Área Postal: MK, Cantidad de Escuelas: 10
# Área Postal: ST, Cantidad de Escuelas: 10
# Área Postal: BH, Cantidad de Escuelas: 10
# Área Postal: TW, Cantidad de Escuelas: 10
# Área Postal: SN, Cantidad de Escuelas: 10
# Área Postal: LE, Cantidad de Escuelas: 9
# Área Postal: NW, Cantidad de Escuelas: 9
# Área Postal: SK, Cantidad de Escuelas: 9
# Área Postal: HP, Cantidad de Escuelas: 9
# Área Postal: NN, Cantidad de Escuelas: 9
# Área Postal: WV, Cantidad de Escuelas: 8
# Área Postal: DL, Cantidad de Escuelas: 8
# Área Postal: EX, Cantidad de Escuelas: 8
# Área Postal: SA, Cantidad de Escuelas: 8
# Área Postal: PE, Cantidad de Escuelas: 8
# Área Postal: NR, Cantidad de Escuelas: 8
# Área Postal: B2, Cantidad de Escuelas: 8
# Área Postal: PL, Cantidad de Escuelas: 8
# Área Postal: N1, Cantidad de Escuelas: 8
# Área Postal: WA, Cantidad de Escuelas: 8
# Área Postal: B1, Cantidad de Escuelas: 7
# Área Postal: NG, Cantidad de Escuelas: 7
# Área Postal: CR, Cantidad de Escuelas: 7
# Área Postal: B7, Cantidad de Escuelas: 7
# Área Postal: S6, Cantidad de Escuelas: 7
# Área Postal: YO, Cantidad de Escuelas: 6
# Área Postal: GL, Cantidad de Escuelas: 6
# Área Postal: E1, Cantidad de Escuelas: 6
# Área Postal: B3, Cantidad de Escuelas: 6
# Área Postal: DT, Cantidad de Escuelas: 6
# Área Postal: DY, Cantidad de Escuelas: 6
# Área Postal: ME, Cantidad de Escuelas: 6
# Área Postal: LN, Cantidad de Escuelas: 6
# Área Postal: B9, Cantidad de Escuelas: 6
# Área Postal: S4, Cantidad de Escuelas: 5
# Área Postal: W1, Cantidad de Escuelas: 5
# Área Postal: N2, Cantidad de Escuelas: 5
# Área Postal: TS, Cantidad de Escuelas: 5
# Área Postal: CW, Cantidad de Escuelas: 5
# Área Postal: NP, Cantidad de Escuelas: 5
# Área Postal: TA, Cantidad de Escuelas: 5
# Área Postal: PR, Cantidad de Escuelas: 5
# Área Postal: UB, Cantidad de Escuelas: 5
# Área Postal: CT, Cantidad de Escuelas: 5
# Área Postal: CF, Cantidad de Escuelas: 5
# Área Postal: SG, Cantidad de Escuelas: 4
# Área Postal: CB, Cantidad de Escuelas: 4
# Área Postal: DH, Cantidad de Escuelas: 4
# Área Postal: HU, Cantidad de Escuelas: 4
# Área Postal: CH, Cantidad de Escuelas: 4
# Área Postal: E3, Cantidad de Escuelas: 4
# Área Postal: CO, Cantidad de Escuelas: 4
# Área Postal: EN, Cantidad de Escuelas: 4
# Área Postal: TQ, Cantidad de Escuelas: 4
# Área Postal: BB, Cantidad de Escuelas: 4
# Área Postal: DA, Cantidad de Escuelas: 4
# Área Postal: HA, Cantidad de Escuelas: 3
# Área Postal: SR, Cantidad de Escuelas: 3
# Área Postal: IG, Cantidad de Escuelas: 3
# Área Postal: RM, Cantidad de Escuelas: 3
# Área Postal: EC, Cantidad de Escuelas: 3
# Área Postal: SM, Cantidad de Escuelas: 3
# Área Postal: LU, Cantidad de Escuelas: 3
# Área Postal: TD, Cantidad de Escuelas: 3
# Área Postal: L1, Cantidad de Escuelas: 3
# Área Postal: TF, Cantidad de Escuelas: 3
# Área Postal: M2, Cantidad de Escuelas: 2
# Área Postal: HR, Cantidad de Escuelas: 2
# Área Postal: M6, Cantidad de Escuelas: 2
# Área Postal: E7, Cantidad de Escuelas: 2
# Área Postal: S1, Cantidad de Escuelas: 2
# Área Postal: B4, Cantidad de Escuelas: 2
# Área Postal: W3, Cantidad de Escuelas: 2
# Área Postal: L2, Cantidad de Escuelas: 2
# Área Postal: M1, Cantidad de Escuelas: 2
# Área Postal: WD, Cantidad de Escuelas: 2
# Área Postal: WN, Cantidad de Escuelas: 2
# Área Postal: S3, Cantidad de Escuelas: 2
# Área Postal: TR, Cantidad de Escuelas: 2
# Área Postal: HG, Cantidad de Escuelas: 2
# Área Postal: S8, Cantidad de Escuelas: 2
# Área Postal: B6, Cantidad de Escuelas: 1
# Área Postal: B5, Cantidad de Escuelas: 1
# Área Postal: KA, Cantidad de Escuelas: 1
# Área Postal: CM, Cantidad de Escuelas: 1
# Área Postal: LS, Cantidad de Escuelas: 1
# Área Postal: HX, Cantidad de Escuelas: 1
# Área Postal: L3, Cantidad de Escuelas: 1
# Área Postal: W5, Cantidad de Escuelas: 1
# Área Postal: PH, Cantidad de Escuelas: 1
# Área Postal: E4, Cantidad de Escuelas: 1
# Área Postal: AL, Cantidad de Escuelas: 1
# Área Postal: PG, Cantidad de Escuelas: 1
# Área Postal: OL, Cantidad de Escuelas: 1
# Área Postal: L7, Cantidad de Escuelas: 1
# Área Postal: S7, Cantidad de Escuelas: 1
# Área Postal: S9, Cantidad de Escuelas: 1
# Área Postal: BT, Cantidad de Escuelas: 1
# Área Postal: E9, Cantidad de Escuelas: 1
# Área Postal: BR, Cantidad de Escuelas: 1
# Área Postal: BD, Cantidad de Escuelas: 1
# Área Postal: W2, Cantidad de Escuelas: 1
# Área Postal: FY, Cantidad de Escuelas: 1
#
# 🔹 Comparando datos entre RDF local y Wikidata...
#
# 📌 Comparación de Escuelas por Área Postal:
#     Área Postal  Escuelas en RDF Local  Escuelas en Wikidata
# 115          RG                      0                    28
# 27           GU                      0                    27
# 122          RH                      0                    23
# 50           OX                      0                    20
# 25           SW                      0                    18
# ..          ...                    ...                   ...
# 105          B5                      0                     1
# 52           B6                      0                     1
# 67           BR                      0                     1
# 97           BT                      0                     1
# 0            OL                      0                     1
#
# [127 rows x 3 columns]

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from IPython.display import display  # Para mostrar tablas en Google Colab

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo RDF cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios desde RDF
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...")

# Ejecutar la consulta en el RDF local
results = g.query(sparql_query)

# Contar colegios por área postal (primeras 2 letras del código postal)
area_counts_local = collections.Counter()

for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer primeras 2 letras
    area_counts_local[area_code] += 1

print("\n📌 Cantidad de escuelas por área postal en RDF local:")
for area, count in sorted(area_counts_local.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- CONSULTA FEDERADA A WIKIDATA ---
print("\n🔹 Consultando cantidad de escuelas en Wikidata por área postal...")

# Definir la consulta SPARQL en Wikidata
wikidata_sparql = """
SELECT ?postcode (COUNT(?school) AS ?count) WHERE {
  # ?school wdt:P31 wd:Q3914;  # Instancia de "escuela"
          wdt:P17 wd:Q145;   # Ubicada en Reino Unido
          wdt:P281 ?postcode. # Código postal
}
GROUP BY ?postcode
"""

# Conectar con Wikidata y ejecutar la consulta
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(wikidata_sparql)
sparql.setReturnFormat(JSON)
results_wikidata = sparql.query().convert()

# Contar colegios por área postal en Wikidata
area_counts_wikidata = collections.Counter()

for result in results_wikidata["results"]["bindings"]:
    postcode = result["postcode"]["value"]  # Obtener código postal
    area_code = postcode[:2]  # Extraer primeras 2 letras
    count = int(result["count"]["value"])  # Convertir a entero
    area_counts_wikidata[area_code] += count  # Contar colegios por área

print("\n📌 Cantidad de escuelas por área postal en Wikidata:")
for area, count in sorted(area_counts_wikidata.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- COMPARAR DATOS ENTRE RDF LOCAL Y WIKIDATA ---
print("\n🔹 Comparando datos entre RDF local y Wikidata...")

# Crear DataFrame para comparar TODAS las áreas postales
data_general = []
for area in set(area_counts_local.keys()).union(area_counts_wikidata.keys()):
    local_count = area_counts_local.get(area, 0)
    wikidata_count = area_counts_wikidata.get(area, 0)
    data_general.append([area, local_count, wikidata_count])

# Convertir a DataFrame
df_general = pd.DataFrame(data_general, columns=["Área Postal", "Escuelas en RDF Local", "Escuelas en Wikidata"])
df_general = df_general.sort_values(by="Escuelas en Wikidata", ascending=False)

# Crear DataFrame solo con áreas postales que existen en el RDF local
data_local_only = []
for area in area_counts_local.keys():  # Solo las áreas postales que están en el RDF
    local_count = area_counts_local[area]
    wikidata_count = area_counts_wikidata.get(area, 0)  # Puede que Wikidata no tenga datos
    data_local_only.append([area, local_count, wikidata_count])

df_local_only = pd.DataFrame(data_local_only, columns=["Área Postal", "Escuelas en RDF Local", "Escuelas en Wikidata"])
df_local_only = df_local_only.sort_values(by="Escuelas en RDF Local", ascending=False)

# --- MOSTRAR RESULTADOS ---
print("\n📌 Comparación General de Escuelas por Área Postal:")
display(df_general)  # Mostrar tabla con TODAS las áreas postales

print("\n📌 Comparación SOLO para áreas postales en RDF local:")
display(df_local_only)  # Mostrar tabla solo con áreas que existen en RDF local
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo RDF cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...
#
# 📌 Cantidad de escuelas por área postal en RDF local:
# Área Postal: DH, Cantidad de Escuelas: 116
# Área Postal: DL, Cantidad de Escuelas: 104
# Área Postal: SR, Cantidad de Escuelas: 30
# Área Postal: TS, Cantidad de Escuelas: 16
# Área Postal: NE, Cantidad de Escuelas: 1
#
# 🔹 Consultando cantidad de escuelas en Wikidata por área postal...
#
# 📌 Cantidad de escuelas por área postal en Wikidata:
# Área Postal: RG, Cantidad de Escuelas: 28
# Área Postal: GU, Cantidad de Escuelas: 27
# Área Postal: RH, Cantidad de Escuelas: 23
# Área Postal: OX, Cantidad de Escuelas: 20
# Área Postal: SW, Cantidad de Escuelas: 18
# Área Postal: KT, Cantidad de Escuelas: 18
# Área Postal: TN, Cantidad de Escuelas: 17
# Área Postal: SE, Cantidad de Escuelas: 16
# Área Postal: SL, Cantidad de Escuelas: 16
# Área Postal: BS, Cantidad de Escuelas: 16
# Área Postal: PO, Cantidad de Escuelas: 15
# Área Postal: SY, Cantidad de Escuelas: 14
# Área Postal: WS, Cantidad de Escuelas: 14
# Área Postal: NE, Cantidad de Escuelas: 14
# Área Postal: SP, Cantidad de Escuelas: 13
# Área Postal: DE, Cantidad de Escuelas: 12
# Área Postal: CV, Cantidad de Escuelas: 12
# Área Postal: DN, Cantidad de Escuelas: 12
# Área Postal: LL, Cantidad de Escuelas: 12
# Área Postal: IP, Cantidad de Escuelas: 11
# Área Postal: BN, Cantidad de Escuelas: 11
# Área Postal: SO, Cantidad de Escuelas: 11
# Área Postal: BA, Cantidad de Escuelas: 11
# Área Postal: WR, Cantidad de Escuelas: 10
# Área Postal: MK, Cantidad de Escuelas: 10
# Área Postal: ST, Cantidad de Escuelas: 10
# Área Postal: BH, Cantidad de Escuelas: 10
# Área Postal: TW, Cantidad de Escuelas: 10
# Área Postal: SN, Cantidad de Escuelas: 10
# Área Postal: LE, Cantidad de Escuelas: 9
# Área Postal: NW, Cantidad de Escuelas: 9
# Área Postal: SK, Cantidad de Escuelas: 9
# Área Postal: HP, Cantidad de Escuelas: 9
# Área Postal: NN, Cantidad de Escuelas: 9
# Área Postal: WV, Cantidad de Escuelas: 8
# Área Postal: DL, Cantidad de Escuelas: 8
# Área Postal: EX, Cantidad de Escuelas: 8
# Área Postal: SA, Cantidad de Escuelas: 8
# Área Postal: PE, Cantidad de Escuelas: 8
# Área Postal: NR, Cantidad de Escuelas: 8
# Área Postal: B2, Cantidad de Escuelas: 8
# Área Postal: PL, Cantidad de Escuelas: 8
# Área Postal: N1, Cantidad de Escuelas: 8
# Área Postal: WA, Cantidad de Escuelas: 8
# Área Postal: B1, Cantidad de Escuelas: 7
# Área Postal: NG, Cantidad de Escuelas: 7
# Área Postal: CR, Cantidad de Escuelas: 7
# Área Postal: B7, Cantidad de Escuelas: 7
# Área Postal: S6, Cantidad de Escuelas: 7
# Área Postal: YO, Cantidad de Escuelas: 6
# Área Postal: GL, Cantidad de Escuelas: 6
# Área Postal: E1, Cantidad de Escuelas: 6
# Área Postal: B3, Cantidad de Escuelas: 6
# Área Postal: DT, Cantidad de Escuelas: 6
# Área Postal: DY, Cantidad de Escuelas: 6
# Área Postal: ME, Cantidad de Escuelas: 6
# Área Postal: LN, Cantidad de Escuelas: 6
# Área Postal: B9, Cantidad de Escuelas: 6
# Área Postal: S4, Cantidad de Escuelas: 5
# Área Postal: W1, Cantidad de Escuelas: 5
# Área Postal: N2, Cantidad de Escuelas: 5
# Área Postal: TS, Cantidad de Escuelas: 5
# Área Postal: CW, Cantidad de Escuelas: 5
# Área Postal: NP, Cantidad de Escuelas: 5
# Área Postal: TA, Cantidad de Escuelas: 5
# Área Postal: PR, Cantidad de Escuelas: 5
# Área Postal: UB, Cantidad de Escuelas: 5
# Área Postal: CT, Cantidad de Escuelas: 5
# Área Postal: CF, Cantidad de Escuelas: 5
# Área Postal: SG, Cantidad de Escuelas: 4
# Área Postal: CB, Cantidad de Escuelas: 4
# Área Postal: DH, Cantidad de Escuelas: 4
# Área Postal: HU, Cantidad de Escuelas: 4
# Área Postal: CH, Cantidad de Escuelas: 4
# Área Postal: E3, Cantidad de Escuelas: 4
# Área Postal: CO, Cantidad de Escuelas: 4
# Área Postal: EN, Cantidad de Escuelas: 4
# Área Postal: TQ, Cantidad de Escuelas: 4
# Área Postal: BB, Cantidad de Escuelas: 4
# Área Postal: DA, Cantidad de Escuelas: 4
# Área Postal: HA, Cantidad de Escuelas: 3
# Área Postal: SR, Cantidad de Escuelas: 3
# Área Postal: IG, Cantidad de Escuelas: 3
# Área Postal: RM, Cantidad de Escuelas: 3
# Área Postal: EC, Cantidad de Escuelas: 3
# Área Postal: SM, Cantidad de Escuelas: 3
# Área Postal: LU, Cantidad de Escuelas: 3
# Área Postal: TD, Cantidad de Escuelas: 3
# Área Postal: L1, Cantidad de Escuelas: 3
# Área Postal: TF, Cantidad de Escuelas: 3
# Área Postal: M2, Cantidad de Escuelas: 2
# Área Postal: HR, Cantidad de Escuelas: 2
# Área Postal: M6, Cantidad de Escuelas: 2
# Área Postal: E7, Cantidad de Escuelas: 2
# Área Postal: S1, Cantidad de Escuelas: 2
# Área Postal: B4, Cantidad de Escuelas: 2
# Área Postal: W3, Cantidad de Escuelas: 2
# Área Postal: L2, Cantidad de Escuelas: 2
# Área Postal: M1, Cantidad de Escuelas: 2
# Área Postal: WD, Cantidad de Escuelas: 2
# Área Postal: WN, Cantidad de Escuelas: 2
# Área Postal: S3, Cantidad de Escuelas: 2
# Área Postal: TR, Cantidad de Escuelas: 2
# Área Postal: HG, Cantidad de Escuelas: 2
# Área Postal: S8, Cantidad de Escuelas: 2
# Área Postal: B6, Cantidad de Escuelas: 1
# Área Postal: B5, Cantidad de Escuelas: 1
# Área Postal: KA, Cantidad de Escuelas: 1
# Área Postal: CM, Cantidad de Escuelas: 1
# Área Postal: LS, Cantidad de Escuelas: 1
# Área Postal: HX, Cantidad de Escuelas: 1
# Área Postal: L3, Cantidad de Escuelas: 1
# Área Postal: W5, Cantidad de Escuelas: 1
# Área Postal: PH, Cantidad de Escuelas: 1
# Área Postal: E4, Cantidad de Escuelas: 1
# Área Postal: AL, Cantidad de Escuelas: 1
# Área Postal: PG, Cantidad de Escuelas: 1
# Área Postal: OL, Cantidad de Escuelas: 1
# Área Postal: L7, Cantidad de Escuelas: 1
# Área Postal: S7, Cantidad de Escuelas: 1
# Área Postal: S9, Cantidad de Escuelas: 1
# Área Postal: BT, Cantidad de Escuelas: 1
# Área Postal: E9, Cantidad de Escuelas: 1
# Área Postal: BR, Cantidad de Escuelas: 1
# Área Postal: BD, Cantidad de Escuelas: 1
# Área Postal: W2, Cantidad de Escuelas: 1
# Área Postal: FY, Cantidad de Escuelas: 1
#
# 🔹 Comparando datos entre RDF local y Wikidata...
#
# 📌 Comparación General de Escuelas por Área Postal:
#     Área Postal  Escuelas en RDF Local  Escuelas en Wikidata
# 115          RG                      0                    28
# 27           GU                      0                    27
# 122          RH                      0                    23
# 50           OX                      0                    20
# 25           SW                      0                    18
# ..          ...                    ...                   ...
# 105          B5                      0                     1
# 52           B6                      0                     1
# 67           BR                      0                     1
# 97           BT                      0                     1
# 0            OL                      0                     1
#
# [127 rows x 3 columns]
# 📌 Comparación SOLO para áreas postales en RDF local:
#   Área Postal  Escuelas en RDF Local  Escuelas en Wikidata
# 2          DH                    116                     4
# 0          DL                    104                     8
# 1          SR                     30                     3
# 3          TS                     16                     5
# 4          NE                      1                    14

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
from rdflib import Graph, Namespace
import collections
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from IPython.display import display  # Para mostrar tablas en Google Colab

# Ruta del archivo RDF en Google Drive
rdf_file_path = "/content/drive/My Drive/output_SchoolsDurham.rdf"

# Cargar el archivo RDF en memoria
g = Graph()
g.parse(rdf_file_path, format="turtle")  # Usamos formato Turtle

print(f"✅ Archivo RDF cargado correctamente. Número de triples: {len(g)}")

# Definir el prefijo correcto basado en la inspección previa
ex = Namespace("http://example.org/schools#")

# Consulta SPARQL para obtener los códigos postales de los colegios desde RDF
sparql_query = """
PREFIX ex: <http://example.org/schools#>
SELECT ?postcode
WHERE {
  # ?school ex:postcode ?postcode .
}
"""

print("\n🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...")

# Ejecutar la consulta en el RDF local
results = g.query(sparql_query)

# Contar colegios por área postal (primeras 2 letras del código postal)
area_counts_local = collections.Counter()

for row in results:
    postcode = str(row.postcode)  # Convertir a string
    area_code = postcode[:2]  # Extraer primeras 2 letras
    area_counts_local[area_code] += 1

print("\n📌 Cantidad de escuelas por área postal en RDF local:")
for area, count in sorted(area_counts_local.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Escuelas: {count}")

# --- CONSULTA FEDERADA A WIKIDATA ---
print("\n🔹 Consultando cantidad de instituciones educativas en Wikidata por área postal...")

# Definir la consulta SPARQL en Wikidata (Incluye múltiples categorías de instituciones educativas)
wikidata_sparql = """
SELECT ?postcode (COUNT(?institution) AS ?count) WHERE {
  # ?institution wdt:P31 ?type;  # Instancia de instituciones educativas
               wdt:P17 wd:Q145;   # Ubicada en Reino Unido
               wdt:P281 ?postcode. # Código postal
  VALUES ?type {
    wd:Q3914    # Schools
    wd:Q1930187 # Academies
    wd:Q8250    # Colegios secundarios
    wd:Q9842    # Colegios primarios
    wd:Q13218630 # Colegios especializados
    wd:Q178706  # Escuelas independientes
  }
}
GROUP BY ?postcode
"""

# Conectar con Wikidata y ejecutar la consulta
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(wikidata_sparql)
sparql.setReturnFormat(JSON)
results_wikidata = sparql.query().convert()

# Contar instituciones educativas por área postal en Wikidata
area_counts_wikidata = collections.Counter()

for result in results_wikidata["results"]["bindings"]:
    postcode = result["postcode"]["value"]  # Obtener código postal
    area_code = postcode[:2]  # Extraer primeras 2 letras
    count = int(result["count"]["value"])  # Convertir a entero
    area_counts_wikidata[area_code] += count  # Contar instituciones por área

print("\n📌 Cantidad de instituciones educativas por área postal en Wikidata:")
for area, count in sorted(area_counts_wikidata.items(), key=lambda x: -x[1]):
    print(f"Área Postal: {area}, Cantidad de Instituciones: {count}")

# --- COMPARAR DATOS ENTRE RDF LOCAL Y WIKIDATA ---
print("\n🔹 Comparando datos entre RDF local y Wikidata...")

# Crear DataFrame para comparar TODAS las áreas postales
data_general = []
for area in set(area_counts_local.keys()).union(area_counts_wikidata.keys()):
    local_count = area_counts_local.get(area, 0)
    wikidata_count = area_counts_wikidata.get(area, 0)
    data_general.append([area, local_count, wikidata_count])

# Convertir a DataFrame
df_general = pd.DataFrame(data_general, columns=["Área Postal", "Escuelas en RDF Local", "Instituciones en Wikidata"])
df_general = df_general.sort_values(by="Instituciones en Wikidata", ascending=False)

# Crear DataFrame solo con áreas postales que existen en el RDF local
data_local_only = []
for area in area_counts_local.keys():  # Solo las áreas postales que están en el RDF
    local_count = area_counts_local[area]
    wikidata_count = area_counts_wikidata.get(area, 0)  # Puede que Wikidata no tenga datos
    data_local_only.append([area, local_count, wikidata_count])

df_local_only = pd.DataFrame(data_local_only, columns=["Área Postal", "Escuelas en RDF Local", "Instituciones en Wikidata"])
df_local_only = df_local_only.sort_values(by="Escuelas en RDF Local", ascending=False)

# --- MOSTRAR RESULTADOS ---
print("\n📌 Comparación General de Instituciones Educativas por Área Postal:")
display(df_general)  # Mostrar tabla con TODAS las áreas postales

print("\n📌 Comparación SOLO para áreas postales en RDF local:")
display(df_local_only)  # Mostrar tabla solo con áreas que existen en RDF local
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo RDF cargado correctamente. Número de triples: 2671
#
# 🔹 Ejecutando consulta SPARQL en RDF local para obtener los códigos postales...
#
# 📌 Cantidad de escuelas por área postal en RDF local:
# Área Postal: DH, Cantidad de Escuelas: 116
# Área Postal: DL, Cantidad de Escuelas: 104
# Área Postal: SR, Cantidad de Escuelas: 30
# Área Postal: TS, Cantidad de Escuelas: 16
# Área Postal: NE, Cantidad de Escuelas: 1
#
# 🔹 Consultando cantidad de instituciones educativas en Wikidata por área postal...
#
# 📌 Cantidad de instituciones educativas por área postal en Wikidata:
# Área Postal: NG, Cantidad de Instituciones: 390
# Área Postal: NE, Cantidad de Instituciones: 371
# Área Postal: PE, Cantidad de Instituciones: 338
# Área Postal: LE, Cantidad de Instituciones: 312
# Área Postal: CF, Cantidad de Instituciones: 309
# Área Postal: DE, Cantidad de Instituciones: 308
# Área Postal: BS, Cantidad de Instituciones: 298
# Área Postal: RG, Cantidad de Instituciones: 293
# Área Postal: DN, Cantidad de Instituciones: 288
# Área Postal: NR, Cantidad de Instituciones: 282
# Área Postal: CV, Cantidad de Instituciones: 271
# Área Postal: GL, Cantidad de Instituciones: 257
# Área Postal: SE, Cantidad de Instituciones: 255
# Área Postal: GU, Cantidad de Instituciones: 250
# Área Postal: NN, Cantidad de Instituciones: 247
# Área Postal: PO, Cantidad de Instituciones: 243
# Área Postal: OX, Cantidad de Instituciones: 240
# Área Postal: TN, Cantidad de Instituciones: 240
# Área Postal: LS, Cantidad de Instituciones: 237
# Área Postal: YO, Cantidad de Instituciones: 231
# Área Postal: EX, Cantidad de Instituciones: 231
# Área Postal: IP, Cantidad de Instituciones: 228
# Área Postal: ST, Cantidad de Instituciones: 227
# Área Postal: SK, Cantidad de Instituciones: 224
# Área Postal: CM, Cantidad de Instituciones: 223
# Área Postal: CH, Cantidad de Instituciones: 219
# Área Postal: WA, Cantidad de Instituciones: 218
# Área Postal: PL, Cantidad de Instituciones: 216
# Área Postal: PR, Cantidad de Instituciones: 210
# Área Postal: ME, Cantidad de Instituciones: 204
# Área Postal: TS, Cantidad de Instituciones: 203
# Área Postal: MK, Cantidad de Instituciones: 202
# Área Postal: BB, Cantidad de Instituciones: 201
# Área Postal: SO, Cantidad de Instituciones: 196
# Área Postal: SA, Cantidad de Instituciones: 193
# Área Postal: BD, Cantidad de Instituciones: 188
# Área Postal: BN, Cantidad de Instituciones: 187
# Área Postal: HP, Cantidad de Instituciones: 185
# Área Postal: SW, Cantidad de Instituciones: 184
# Área Postal: SN, Cantidad de Instituciones: 182
# Área Postal: RH, Cantidad de Instituciones: 180
# Área Postal: WF, Cantidad de Instituciones: 180
# Área Postal: BA, Cantidad de Instituciones: 174
# Área Postal: OL, Cantidad de Instituciones: 173
# Área Postal: DL, Cantidad de Instituciones: 169
# Área Postal: SG, Cantidad de Instituciones: 166
# Área Postal: CA, Cantidad de Instituciones: 161
# Área Postal: WS, Cantidad de Instituciones: 154
# Área Postal: SY, Cantidad de Instituciones: 149
# Área Postal: NP, Cantidad de Instituciones: 149
# Área Postal: CO, Cantidad de Instituciones: 146
# Área Postal: KT, Cantidad de Instituciones: 143
# Área Postal: CB, Cantidad de Instituciones: 142
# Área Postal: E1, Cantidad de Instituciones: 140
# Área Postal: LL, Cantidad de Instituciones: 140
# Área Postal: CT, Cantidad de Instituciones: 139
# Área Postal: BL, Cantidad de Instituciones: 139
# Área Postal: TA, Cantidad de Instituciones: 137
# Área Postal: RM, Cantidad de Instituciones: 133
# Área Postal: HU, Cantidad de Instituciones: 133
# Área Postal: N1, Cantidad de Instituciones: 132
# Área Postal: NW, Cantidad de Instituciones: 127
# Área Postal: WV, Cantidad de Instituciones: 125
# Área Postal: SS, Cantidad de Instituciones: 124
# Área Postal: DH, Cantidad de Instituciones: 123
# Área Postal: BH, Cantidad de Instituciones: 123
# Área Postal: TR, Cantidad de Instituciones: 121
# Área Postal: TW, Cantidad de Instituciones: 120
# Área Postal: DY, Cantidad de Instituciones: 120
# Área Postal: LN, Cantidad de Instituciones: 120
# Área Postal: SL, Cantidad de Instituciones: 119
# Área Postal: SP, Cantidad de Instituciones: 117
# Área Postal: DA, Cantidad de Instituciones: 116
# Área Postal: LA, Cantidad de Instituciones: 116
# Área Postal: CW, Cantidad de Instituciones: 114
# Área Postal: WR, Cantidad de Instituciones: 111
# Área Postal: WN, Cantidad de Instituciones: 111
# Área Postal: CR, Cantidad de Instituciones: 106
# Área Postal: S6, Cantidad de Instituciones: 106
# Área Postal: M2, Cantidad de Instituciones: 104
# Área Postal: B7, Cantidad de Instituciones: 99
# Área Postal: LU, Cantidad de Instituciones: 99
# Área Postal: HA, Cantidad de Instituciones: 97
# Área Postal: TQ, Cantidad de Instituciones: 94
# Área Postal: UB, Cantidad de Instituciones: 94
# Área Postal: EN, Cantidad de Instituciones: 93
# Área Postal: HD, Cantidad de Instituciones: 91
# Área Postal: WD, Cantidad de Instituciones: 88
# Área Postal: AL, Cantidad de Instituciones: 87
# Área Postal: B1, Cantidad de Instituciones: 86
# Área Postal: B6, Cantidad de Instituciones: 84
# Área Postal: B3, Cantidad de Instituciones: 84
# Área Postal: B2, Cantidad de Instituciones: 82
# Área Postal: TF, Cantidad de Instituciones: 80
# Área Postal: HR, Cantidad de Instituciones: 79
# Área Postal: DT, Cantidad de Instituciones: 78
# Área Postal: L3, Cantidad de Instituciones: 78
# Área Postal: BR, Cantidad de Instituciones: 77
# Área Postal: SR, Cantidad de Instituciones: 76
# Área Postal: B9, Cantidad de Instituciones: 76
# Área Postal: S4, Cantidad de Instituciones: 73
# Área Postal: S7, Cantidad de Instituciones: 72
# Área Postal: M3, Cantidad de Instituciones: 72
# Área Postal: IG, Cantidad de Instituciones: 70
# Área Postal: L1, Cantidad de Instituciones: 70
# Área Postal: HX, Cantidad de Instituciones: 67
# Área Postal: FY, Cantidad de Instituciones: 67
# Área Postal: M1, Cantidad de Instituciones: 64
# Área Postal: HG, Cantidad de Instituciones: 63
# Área Postal: M4, Cantidad de Instituciones: 63
# Área Postal: B4, Cantidad de Instituciones: 55
# Área Postal: L2, Cantidad de Instituciones: 54
# Área Postal: SM, Cantidad de Instituciones: 51
# Área Postal: S1, Cantidad de Instituciones: 51
# Área Postal: S2, Cantidad de Instituciones: 48
# Área Postal: W1, Cantidad de Instituciones: 45
# Área Postal: S3, Cantidad de Instituciones: 42
# Área Postal: S8, Cantidad de Instituciones: 35
# Área Postal: N2, Cantidad de Instituciones: 28
# Área Postal: L4, Cantidad de Instituciones: 26
# Área Postal: LD, Cantidad de Instituciones: 18
# Área Postal: B8, Cantidad de Instituciones: 16
# Área Postal: E3, Cantidad de Instituciones: 15
# Área Postal: E2, Cantidad de Instituciones: 15
# Área Postal: E6, Cantidad de Instituciones: 15
# Área Postal: TD, Cantidad de Instituciones: 14
# Área Postal: EC, Cantidad de Instituciones: 13
# Área Postal: E4, Cantidad de Instituciones: 13
# Área Postal: S5, Cantidad de Instituciones: 13
# Área Postal: E7, Cantidad de Instituciones: 12
# Área Postal: W3, Cantidad de Instituciones: 12
# Área Postal: M9, Cantidad de Instituciones: 12
# Área Postal: S9, Cantidad de Instituciones: 11
# Área Postal: N9, Cantidad de Instituciones: 11
# Área Postal: E5, Cantidad de Instituciones: 11
# Área Postal: W6, Cantidad de Instituciones: 11
# Área Postal: M6, Cantidad de Instituciones: 10
# Área Postal: E9, Cantidad de Instituciones: 10
# Área Postal: M8, Cantidad de Instituciones: 10
# Área Postal: M7, Cantidad de Instituciones: 10
# Área Postal: W2, Cantidad de Instituciones: 9
# Área Postal: N8, Cantidad de Instituciones: 9
# Área Postal: E8, Cantidad de Instituciones: 9
# Área Postal: N4, Cantidad de Instituciones: 9
# Área Postal: W5, Cantidad de Instituciones: 8
# Área Postal: L7, Cantidad de Instituciones: 8
# Área Postal: N3, Cantidad de Instituciones: 8
# Área Postal: L8, Cantidad de Instituciones: 8
# Área Postal: W4, Cantidad de Instituciones: 8
# Área Postal: N7, Cantidad de Instituciones: 7
# Área Postal: L9, Cantidad de Instituciones: 6
# Área Postal: W9, Cantidad de Instituciones: 6
# Área Postal: W7, Cantidad de Instituciones: 6
# Área Postal: N5, Cantidad de Instituciones: 5
# Área Postal: L5, Cantidad de Instituciones: 5
# Área Postal: M5, Cantidad de Instituciones: 5
# Área Postal: L6, Cantidad de Instituciones: 4
# Área Postal: WC, Cantidad de Instituciones: 4
# Área Postal: BT, Cantidad de Instituciones: 3
# Área Postal: W8, Cantidad de Instituciones: 3
# Área Postal: N6, Cantidad de Instituciones: 3
# Área Postal: B5, Cantidad de Instituciones: 2
# Área Postal: G7, Cantidad de Instituciones: 2
# Área Postal: ML, Cantidad de Instituciones: 2
# Área Postal: KA, Cantidad de Instituciones: 1
# Área Postal: PH, Cantidad de Instituciones: 1
# Área Postal: PG, Cantidad de Instituciones: 1
# Área Postal: G3, Cantidad de Instituciones: 1
# Área Postal: FK, Cantidad de Instituciones: 1
#
# 🔹 Comparando datos entre RDF local y Wikidata...
#
# 📌 Comparación General de Instituciones Educativas por Área Postal:
#     Área Postal  Escuelas en RDF Local  Instituciones en Wikidata
# 59           NG                      0                        390
# 9            NE                      1                        371
# 70           PE                      0                        338
# 129          LE                      0                        312
# 68           CF                      0                        309
# ..          ...                    ...                        ...
# 167          KA                      0                          1
# 38           PH                      0                          1
# 116          G3                      0                          1
# 150          FK                      0                          1
# 118          PG                      0                          1
#
# [169 rows x 3 columns]
# 📌 Comparación SOLO para áreas postales en RDF local:
#   Área Postal  Escuelas en RDF Local  Instituciones en Wikidata
# 2          DH                    116                        123
# 0          DL                    104                        169
# 1          SR                     30                         76
# 3          TS                     16                        203
# 4          NE                      1                        371
